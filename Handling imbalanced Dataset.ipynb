# %% [markdown]
# **Imbalanced Dataset:**

# %%
# importing the dependencies
import numpy as np
import pandas as pd

# %%
 #loading the dataset to pandas DataFrame
credit_card_data = pd.read_csv('/content/credit_data.csv')

# %%
# first 5 rows of the dataframe
credit_card_data.head()
# Out:
#    Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 0     0 -1.359807 -0.072781  2.536347  ...  0.133558 -0.021053  149.62    0.0
# 1     0  1.191857  0.266151  0.166480  ... -0.008983  0.014724    2.69    0.0
# 2     1 -1.358354 -1.340163  1.773209  ... -0.055353 -0.059752  378.66    0.0
# 3     1 -0.966272 -0.185226  1.792993  ...  0.062723  0.061458  123.50    0.0
# 4     2 -1.158233  0.877737  1.548718  ...  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
credit_card_data.tail()
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 17500  28773 -0.430412  1.018080  1.560273  ...  0.263548  0.121474    5.38    0.0
# 17501  28774 -1.184230  1.025272  1.722521  ...  0.053304  0.109783    3.99    0.0
# 17502  28775  1.067437 -0.828109  0.456921  ...  0.056720  0.054231  158.00    0.0
# 17503  28776 -6.392357  4.547807 -7.610294  ...  0.041010 -0.266988   89.99    0.0
# 17504  28777  0.877247 -0.990305  0.565650  ...       NaN       NaN     NaN    NaN
#
# [5 rows x 31 columns]

# %%
# distribution of the two classes
credit_card_data['Class'].value_counts()
# Out:
# 0.0    17423
# 1.0       81
# Name: Class, dtype: int64

# %% [markdown]
# This is Highly Imbalanced Dataset

# %%
# separating the legit and fraudulent transactions
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

print(legit.shape)
print(fraud.shape)
# Out:
# (17423, 31)
# (81, 31)

# %% [markdown]
# Under-sampling

# %%
legit_sample = legit.sample(n=81)

# %%
print(legit_sample.shape)
# Out:
# (81, 31)

# %% [markdown]
# Concatenate the Two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis = 0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3  ...       V27       V28  Amount  Class
# 8363   11182  1.255067 -0.448434  0.155666  ... -0.054295  0.021856   99.99    0.0
# 1984    1525 -0.342132  1.091125  1.282729  ...  0.241932  0.097139    3.59    0.0
# 16470  27846  1.245815 -0.062004  0.428500  ... -0.018024  0.007212   12.36    0.0
# 2993    2545 -0.756466  0.940557  2.161140  ... -0.026546  0.043833    5.80    0.0
# 7431   10052  1.275517  0.108176  0.748790  ... -0.095134  0.005186    8.00    0.0
#
# [5 rows x 31 columns]

# %%
new_dataset.tail()
# Out:
#         Time         V1         V2  ...       V28  Amount  Class
# 17317  28625 -27.848181  15.598193  ...  0.388090   99.99    1.0
# 17366  28658 -28.524268  15.876923  ...  0.380246   99.99    1.0
# 17407  28692 -29.200329  16.155701  ...  0.372393   99.99    1.0
# 17453  28726 -29.876366  16.434525  ...  0.364530   99.99    1.0
# 17480  28755 -30.552380  16.713389  ...  0.356660   99.99    1.0
#
# [5 rows x 31 columns]

# %%
new_dataset['Class'].value_counts()
# Out:
# 1.0    81
# 0.0    81
# Name: Class, dtype: int64
